# %% [markdown]
# <a href="https://colab.research.google.com/github/AnayaThombare/python_1/blob/main/code_experiments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
color = ["red","orange","yellow","green","blue","purple","pink"]

inp = input("Enter your fave color. It can be red, orange, yellow, green, blue, purple, or pink.(only in lowercase)")

if inp in color:
  ani = inp
  print(f"You chose {ani}! Have a nice day!")
  amin = input("What is your fave, cat or dog?")

else:
  print("I'm sorry, but that is not one of the options to choose from. Have a nice day!")
# Out:
# Enter your fave color. It can be red, orange, yellow, green, blue, purple, or pink.(only in lowercase)green
# You chose green! Have a nice day!
# What is your fave, cat or dog?gr

# %%
superheroes = ["Iron Man", "Ms. Marvel","Wonder Woman"]

for superhero in superheroes:
  print(superhero)
# Out:
# Iron Man
# Ms. Marvel
# Wonder Woman
